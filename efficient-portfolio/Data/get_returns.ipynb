# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
file_name = 'stock_returns.csv'
lista = os.listdir()[1:]
lista.remove('get_returns.ipynb')
if file_name in lista:
    lista.remove(file_name)

# %%
stock_returns = []
i = 0
for csv_file in lista:
    file = pd.read_csv(csv_file)
    returns = [100*(file['Adj Close'][i]/file['Adj Close'][i+1] -1) for i in range(file.Close.shape[0]-1)]
    stock_returns.append(returns) 
    i+=1

# %%
with open(file_name, 'w') as new_file:    
    for j in range(len(stock_returns[0])):
        for i in range(len(stock_returns)):
            if i < len(stock_returns)-1: new_file.write(str(round(stock_returns[i][j],4))+';')
            else: new_file.write(str(round(stock_returns[i][j],4)))
        new_file.write('\n')

# %%
data = pd.read_csv(file_name, sep=';', header=None)
data.head()
# Out:
#        0       1       2        3       4       5       6       7       8   \
# 0 -0.2280  4.6478 -0.9601  -2.3151 -0.4397  2.1622 -0.3027  0.1658  3.5793
# 1  0.3619  2.4148  1.3473 -12.8445 -0.1686  0.5435  2.1590  4.1437  0.3960
# 2  0.2133  0.1932 -3.3285  -1.3113 -0.7397  0.0000 -1.5941 -1.7972 -2.0402
# 3  0.3371  0.2091  0.6555  -0.1455 -0.2903  2.2222  1.7123  1.1364  1.9780
# 4 -1.7715 -3.3104 -4.6528   0.3895 -0.7262  0.0000 -1.2783 -1.2245 -0.8715
#
#        9    ...        43      44      45      46      47      48      49  \
# 0  3.7651   ...    2.9109 -0.4144 -0.0895  5.4870 -0.3586 -0.7261  0.4647
# 1  0.2111   ...    9.9812  1.2057  1.0250  1.6971 -1.7303  0.5589  1.2260
# 2  1.5541   ...   -2.9250 -0.4349  1.3753 -2.7623 -2.7286 -0.8136 -0.7272
# 3 -1.4003   ...    0.1831  1.4293  0.1837  0.6227  2.4550 -0.0536 -0.0612
# 4 -0.5518   ...   -1.9749 -0.4217  1.4916 -2.7556 -2.4296 -2.5174 -0.0994
#
#        50      51      52
# 0  1.0737  0.2370  0.2363
# ...
